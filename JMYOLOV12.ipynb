# %% [markdown]
# <a href="https://colab.research.google.com/github/Bidhan-saha/YOLO/blob/main/JMYOLOV12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Sep  4 07:51:49 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.5 MB/s eta 0:00:00
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
from ultralytics import YOLO

# Build a new model from your custom YAML
model = YOLO('/content/yolo12.yaml')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# WARNING ⚠️ no model scale passed. Assuming scale='n'.

# %%
# !unzip /content/pneumonia-and-normal.v3-ml2jmv1.yolov12.zip
# Out:
# Archive:  /content/pneumonia-and-normal.v3-ml2jmv1.yolov12.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/IM-0119-0001_jpeg.rf.86c0ec34e22404270243bbd0457a1f15.jpg
#  extracting: test/images/IM-0147-0001_jpeg.rf.03401feb0d35a2669618f86f46896e08.jpg
#  extracting: test/images/IM-0152-0001_jpeg.rf.f4e079eb9a488065409e05a3dd6be5f7.jpg
#  extracting: test/images/IM-0162-0001_jpeg.rf.97d5f60c206551885c6c0acefc4d6468.jpg
#  extracting: test/images/IM-0180-0001_jpeg.rf.63b38980a95b4e18633787a83d22b1e6.jpg
#  extracting: test/images/IM-0183-0001_jpeg.rf.99ab80af3f327dcd91dc9781e0f13c2c.jpg
#  extracting: test/images/IM-0205-0001_jpeg.rf.d3f592e806dc7b4270bc182be775973e.jpg
#  extracting: test/images/IM-0207-0001_jpeg.rf.415745b763cc2f1b6953632eedc733b2.jpg
#  extracting: test/images/IM-0223-0001_jpeg.rf.d75c86814decbd4ee8134ff45ca2fcdf.jpg
# ...

# %%
model = YOLO("/content/yolo12.yaml")   # upload yaml data path run
model.train(data="/content/data.yaml", epochs=25 , imgsz=512, batch=16 )
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Ultralytics 8.3.192 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
